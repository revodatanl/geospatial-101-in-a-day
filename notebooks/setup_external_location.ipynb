# %%
# %sql
CREATE SCHEMA IF NOT EXISTS geospatial.inputs;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS geospatial.outputs;

# %%
# %sql
CREATE EXTERNAL VOLUME IF NOT EXISTS geospatial.inputs.geospatial_dataset
LOCATION 's3://revodata-databricks-geospatial/geospatial-dataset/';

# %%
# %sql
CREATE EXTERNAL VOLUME IF NOT EXISTS geospatial.inputs.inits
LOCATION 's3://revodata-databricks-geospatial/init-scripts/';

# %%
# %sql
CREATE EXTERNAL VOLUME IF NOT EXISTS geospatial.outputs.geojson
LOCATION 's3://revodata-databricks-geospatial/outputs/geojson/';

# %%
# %sql
CREATE EXTERNAL VOLUME IF NOT EXISTS geospatial.outputs.geotiff
LOCATION 's3://revodata-databricks-geospatial/outputs/geotiff/';

# %%
# %sql
CREATE EXTERNAL VOLUME IF NOT EXISTS geospatial.outputs.geopackage
LOCATION 's3://revodata-databricks-geospatial/outputs/geopackage/';
