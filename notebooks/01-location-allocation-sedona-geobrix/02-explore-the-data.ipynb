# %% [markdown]
# ## Goal
#
# The objective of this notebook is to explore the ingested data in the previous step and learn some basic visualizations of the data.

# %%
# %sql
DESCRIBE EXTENDED geospatial.lookups.boundary_line_ceremonial_counties_USERNAME;

# %%
# %sql
SELECT DISTINCT function
FROM geospatial.greenspaces.greenspace_site_USERNAME;
ORDER BY function;

# %%
# %sql
SELECT DISTINCT ga.access_type FROM geospatial.greenspaces.access_point_USERNAME ga

# %%
# %sql
SELECT COUNT(*)
FROM geospatial.greenspaces.greenspace_site_USERNAME
WHERE function IN ('Play Space', 'Playing Field', 'Public Park Or Garden');

# %%
config = SedonaContext.builder() .\
    config('spark.jars.packages',
           'org.apache.sedona:sedona-spark-shaded-3.3_2.12:1.7.1,'
           'org.datasyslab:geotools-wrapper:1.7.1-28.5'). \
    getOrCreate()
sedona = SedonaContext.create(config)

# %%
access_point_df  = spark.sql("""
  SELECT fid, access_type, geometry
  FROM geospatial.greenspaces.access_point_melikasajadian
  WHERE access_type = 'Pedestrian'
""").limit(500)

# %%
map = SedonaKepler.create_map()
SedonaKepler.add_df(map, access_point_df, name="park access points")
map
